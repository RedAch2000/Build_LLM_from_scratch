# %% [markdown]
# # BYTE PAIR ENCODING

# %%
# !pip3 install tiktoken
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tiktoken in C:\Users\reda\AppData\Roaming\Python\Python314\site-packages (0.13.0)
# Requirement already satisfied: regex in C:\Users\reda\AppData\Roaming\Python\Python314\site-packages (from tiktoken) (2026.5.9)
# Requirement already satisfied: requests in C:\Users\reda\AppData\Roaming\Python\Python314\site-packages (from tiktoken) (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\reda\AppData\Roaming\Python\Python314\site-packages (from requests->tiktoken) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\reda\AppData\Roaming\Python\Python314\site-packages (from requests->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\reda\AppData\Roaming\Python\Python314\site-packages (from requests->tiktoken) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\reda\AppData\Roaming\Python\Python314\site-packages (from requests->tiktoken) (2026.2.25)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Python314\python.exe -m pip install --upgrade pip

# %%
import importlib
import tiktoken

print("tiktoken version:", importlib.metadata.version("tiktoken"))
# Out:
# tiktoken version: 0.12.0

# %% [markdown]
# ### GTP tokenizer

# %% [markdown]
# #### initialize the tokenizer

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %% [markdown]
# #### Encoding text into token ids

# %%
text = (
    "Hello, do you like tea? <|endoftext|> In the sunlit terraces"
     "of someunknownPlace."
)

token_ids = tokenizer.encode(text, allowed_special={"<|endoftext|>"})

print(token_ids)
# Out:
# [15496, 11, 466, 345, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 1659, 617, 34680, 27271, 13]

# %% [markdown]
# #### Decoding token ids into text

# %%
strings = tokenizer.decode(token_ids)

print(strings)
# Out:
# Hello, do you like tea? <|endoftext|> In the sunlit terracesof someunknownPlace.

# %%
integers = tokenizer.encode("Reda Achouhad")
print(integers)

strings = tokenizer.decode(integers)
print(strings)
# Out:
# [7738, 64, 26219, 280, 18108]
# Reda Achouhad

# %% [markdown]
# ### **Data sampling with sliding window**

# %%
with open("../the-verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

enc_text = tokenizer.encode(raw_text)
print(len(enc_text))
# Out:
# 5145

# %%
enc_sample = enc_text[50:]

# %%
context_size = 4

x = enc_sample[:context_size]
y = enc_sample[1:context_size + 1]

print(f"x: {x}")
print(f"y:      {y}")
# Out:
# x: [290, 4920, 2241, 287]
# y:      [4920, 2241, 287, 257]

# %%
for i in range(1, context_size+1):
    context = enc_sample[:i]
    desired = enc_sample[i]

    print(context, "---->", desired)
# Out:
# [290] ----> 4920
# [290, 4920] ----> 2241
# [290, 4920, 2241] ----> 287
# [290, 4920, 2241, 287] ----> 257

# %%
for i in range(1, context_size+1):
    context = enc_sample[:i]
    desired = enc_sample[i]

    print(tokenizer.decode(context), "---->", tokenizer.decode([desired]))
# Out:
#  and ---->  established
#  and established ---->  himself
#  and established himself ---->  in
#  and established himself in ---->  a
